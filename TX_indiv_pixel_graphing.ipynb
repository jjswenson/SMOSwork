# %%
#new stuff-- July 2020
import pandas as pd, numpy as np
import os
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#starting out- read in file and set programs
os.chdir("D:/Research/Texas_drought/RadarTexas/")
Tx_deathlvodacc = pd.read_csv(r"Variables/FromPython/ALLCells2020/TX_deathLVOD_descasc_springAcc.csv")
list(Tx_deathlvodacc)

os.chdir("D:/Research/Texas_drought/RadarTexas/")
sns.relplot(x="Spring Average LVOD Accumulation", y="Spring 2011 LVOD Accumulation", hue="Live canopy %", size="Canopy loss %",
           alpha=1, height=10, sizes=(10, 200), data=Tx_deathlvodacc)

# %%
sns.relplot(x="Canopy loss %", y="Spring 2011 LVOD Accumulation", hue="Live canopy %", #size="Canopy loss %",
           alpha=1, height=10, sizes=(10, 200), data=Tx_deathlvodacc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1b83a9cb70a5> in <module>
# ----> 1 sns.relplot(x="Canopy loss %", y="Spring 2011 LVOD Accumulation", hue="Live canopy %", #size="Canopy loss %",
#       2            alpha=1, height=10, sizes=(10, 200), data=Tx_deathlvodacc)
#
# NameError: name 'sns' is not defined

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os
os.chdir("D:/Research/Texas_drought/RadarTexas/")
sns.set(style="whitegrid")
year = '2010'
year2 = '2011'
year3 = '2012'
#would be good to insert a label in these...
#select 1 year differences
CONUS_DescLVODMonthMeans = pd.read_csv(r"Variables/FromPython/CONUS_DescLVODMonthlyMeansGSNO0x.csv")
CONUS_DescLVODMonthMeans.set_index(['ID'])
# Out:
#        Unnamed: 0  2010-03-31 00:00:00  2010-04-30 00:00:00  \
# ID
# 881           881                  NaN                  NaN
# 882           882                  NaN                  NaN
# 883           883                  NaN             0.570913
# 987           987                  NaN                  NaN
# 988           988             0.590638             0.624712
# 989           989                  NaN                  NaN
# 993           993                  NaN                  NaN
# 994           994             0.650659             0.685150
# 995           995             0.709420             0.741566
# 996           996             0.730004             0.785754
# 997           997             0.642960             0.718794
# 999           999             0.555701             0.627890
# 1000         1000                  NaN                  NaN
# 1013         1013                  NaN                  NaN
# 1014         1014             0.734837             0.732786
# ...

# %%
#import data
CONUS_DescLVODMonthMeans
# Out:
#        Unnamed: 0     ID  2010-03-31 00:00:00  2010-04-30 00:00:00  \
# 0             881    881                  NaN                  NaN
# 1             882    882                  NaN                  NaN
# 2             883    883                  NaN             0.570913
# 3             987    987                  NaN                  NaN
# 4             988    988             0.590638             0.624712
# 5             989    989                  NaN                  NaN
# 6             993    993                  NaN                  NaN
# 7             994    994             0.650659             0.685150
# 8             995    995             0.709420             0.741566
# 9             996    996             0.730004             0.785754
# 10            997    997             0.642960             0.718794
# 11            999    999             0.555701             0.627890
# 12           1000   1000                  NaN                  NaN
# ...

# %%
#select year
#DesMonthMn11 = CONUS_DescLVODMonthMeans.filter(regex='2011')
#select pixels to plot 40% of 93, 48% of 91, 47% of 67
hican_hideath = [11318, 11992, 12106]
# 1% of 66, 5% of 92%, 7% of 92
hican_lowdeath = [11437, 4216, 11766]

# %%
Candeath = DesMonthMn11.loc[hican_hideath]
NoCanDeath = DesMonthMn11.loc[hican_lowdeath]
Candeath.set_index(Candeath.index).T.plot().legend(loc='center left', title="DESC LVOD", bbox_to_anchor=(1, 0.5))
plt.axis(['2015-01', '2016-01', 0, .9])
plt.show()
NoCanDeath.set_index(NoCanDeath.index).T.plot().legend(loc='center left', title="DESC LVOD", bbox_to_anchor=(1, 0.5))
plt.axis(['2015-01', '2016-01', 0, .9])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-96ae7528b936> in <module>
# ----> 1 Candeath = DesMonthMn11.loc[hican_hideath]
#       2 NoCanDeath = DesMonthMn11.loc[hican_lowdeath]
#       3 Candeath.set_index(Candeath.index).T.plot().legend(loc='center left', title="DESC LVOD", bbox_to_anchor=(1, 0.5))
#       4 plt.axis(['2015-01', '2016-01', 0, .9])
#       5 plt.show()
#
# NameError: name 'DesMonthMn11' is not defined
